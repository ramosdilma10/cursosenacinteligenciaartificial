# %% [markdown]
# <a href="https://colab.research.google.com/github/ramosdilma10/cursosenacinteligenciaartificial/blob/main/UC3_probabilidade_senac.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # UC3 — Probabilidade aplicada à IA
#
# ## Objetivo
# * Aprender o Principio Fundamental da Contagem (PFC)
# * Aprender probabilidade
# * conectar com IA

# %% [markdown]
# Antes de iniciarmos com a probabilidade, é importantes falarmos sobre o Principio Fundamental da Contagem.

# %% [markdown]
# # Princípio Fundamental da Contagem (PFC)

# %% [markdown]
# ##  O que é?
#
# O Princípio Fundamental da Contagem diz:
#
# > Se um processo ocorre em etapas independentes, multiplicamos as possibilidades de cada etapa.
#
# ---
#
# ## Intuição
#
# Se você tem escolhas em sequência, você **multiplica**.
#
# ---

# %% [markdown]
# ##  Exemplo 1 — Roupas
#
# - 3 camisetas
# - 2 calças
#
# Quantos looks diferentes?
#
# $$
# 3 \times 2 = 6
# $$
#
# ---

# %% [markdown]
# ##  Exemplo 2 — Moeda + Dado
#
# - Moeda → 2 opções (cara, coroa)
# - Dado → 6 opções
#
# Total de possibilidades:
#
# $$
# 2 \times 6 = 12
# $$
#
# ---

# %% [markdown]
# ##  Conexão com Probabilidade
#
# A probabilidade é dada por:
#
# $$
# P(A) = \frac{\text{casos favoráveis}}{\text{casos possíveis}}
# $$
#
# 👉 O PFC nos ajuda a encontrar o **total de casos possíveis**.
#
# ---

# %% [markdown]
# ## 📌 Exemplo aplicado
#
# Qual a probabilidade de tirar **cara e depois o número 6**?
#
# - Total de possibilidades: 12
# - Casos favoráveis: 1
#
# $$
# P = \frac{1}{12}
# $$
#
# ---

# %%
print(f"A probabilidade e: {(1/12)*100}%")
# Out:
# A probabilidade e: 8.333333333333332%

# %% [markdown]
# ##  Exercício
#
# 1. Quantas combinações são possíveis com:
#    - 4 tipos de camiseta
#    - 3 tipos de calça
#      4*3=12
# 2. Quantos resultados possíveis ao lançar:
#    - uma moeda
#    - um dado
#    - outro dado
#       2*(6)*6=72
# ---

# %% [markdown]
# ## Conexão com IA
#
# Em Inteligência Artificial, usamos isso para entender:
#
# - Quantidade de combinações possíveis
# - Espaço de busca
# - Complexidade de problemas
#
#  Exemplo:
# - combinações de palavras em um texto
# - pixels em uma imagem
# - decisões possíveis de um modelo
#
# ---

# %% [markdown]
# ##  Conclusão
#
# 👉 Se tem etapas → multiplica
# 👉 Isso define o espaço de possibilidades
# 👉 E isso é a base da probabilidade

# %% [markdown]
# ## 1. Conceito fundamental
#
# Probabilidade mede a chance de um evento acontecer:
#
# $$
# P(A) = \frac{\text{casos favoráveis}}{\text{casos possíveis}}
# $$
#
# Exemplo:
# Dado → pares = {2,4,6}`   P(A)=3/6
#
# P(par) = 3/6 = 0.5

# %%
# exemplo simples
pares = [2, 4, 6]
dado = [1, 2, 3, 4, 5, 6]
probabilidade = len(pares) / len(dado)
print(f'A probabilidade e: {probabilidade*100}%')
# Out:
# A probabilidade e: 50.0%

# %% [markdown]
# ## 2. Espaço amostral
#
# Espaço amostral = todos os resultados possíveis
#
# Ex:
# Dado → {1,2,3,4,5,6}
#
# Evento = subconjunto  # e o que quero saber
#
# Ex: números pares

# %% [markdown]
# ## 3. Exercício guiado
#
# Qual a probabilidade de sair número maior que 4?

# %%
dado=[1, 2, 3, 4, 5, 6]
evento=[5,6]
probabilidade=len(evento)/dado
print(f'A probabilidade e: {probabilidade*100}%')
# Out:
# A probabilidade e: 33.33333333333333%

# %% [markdown]
# ## 4. Eventos independentes
#
# Eventos independentes → um não afeta o outro
#
# Ex:
# Moeda + dado
#
# P(cara E 6) = 1/2 * 1/6 = 1/12

# %%
possibilidades=2*6
evento=1
probabilidade=evento/possibilidades
print(f'A probabilidade de sair cara e 6 e: {probabilidade*100}%')
# Out:
# A probabilidade de sair cara e 6 e: 8.333333333333332%

# %% [markdown]
# ## 5. Eventos dependentes (intuição)
#
# Se retirar carta sem reposição → muda a probabilidade
#
# Isso é MUITO importante para IA (dados mudam!)

# %% [markdown]
# EXEMPLO 1: CARTAS

# %% [markdown]
# “Se eu tiro uma carta e NÃO devolvo… o baralho muda.”

# %%
cartas = ["❤️", "❤️", "♠", "♠"]

# %% [markdown]
# Qual a probabilidade de tirar duas cartas ❤️ seguidas sem reposição?

# %% [markdown]
# 1ª carta:
#
# * 2/4 = 1/2
#
# 2ª carta:
#
# agora só sobram 3 cartas
# apenas 1 é ❤️
#
# * 1/3

# %% [markdown]
# P = 1/2 * 1/3 = 1/6

# %%
1/6
# Out:
# 0.16666666666666666

# %%
#random - qdo eu quero pegar um evento aleatorio
import random

cartas = ["❤️", "❤️", "♠", "♠"]

sucesso = 0
n = 10000

for _ in range(n):
    baralho = cartas.copy()
    c1 = random.choice(baralho)
    baralho.remove(c1)

    c2 = random.choice(baralho)

    if c1 == "❤️" and c2 == "❤️":
        sucesso += 1

sucesso / n
# Out:
# 0.1642

# %% [markdown]
# EXEMPLO 2 — ALUNOS

# %% [markdown]
# “Imagina que eu tenho uma turma com 3 alunos bons em Python e 2 iniciantes.”

# %% [markdown]
# Qual a probabilidade de escolher 2 alunos bons seguidos sem reposição?

# %% [markdown]
# 1º aluno:
#
# * 3/5
#
# 2º aluno:
#
# agora só restam 4 alunos
# 2 são bons
#
# * 2/4 = 1/2

# %%
P= (3/5)*(2/4)
P= 6/20
P= 3/10
P= 0.3333

# %%
alunos = ["bom", "bom", "bom", "iniciante", "iniciante"]

# %%
sucesso = 0
n = 10000

for _ in range(n):
    turma = alunos.copy()

    a1 = random.choice(turma)
    turma.remove(a1)

    a2 = random.choice(turma)

    if a1 == "bom" and a2 == "bom":
        sucesso += 1

sucesso / n
# Out:
# 0.3005

# %% [markdown]
# ## 6. Frequência vs probabilidade
#
# Vamos simular:

# %%
import random

n=10000
caras=0

for _ in range(n):
    if random.choice(["cara","coroa"])=="cara":
        caras+=1

caras/n
# Out:
# 0.4996

# %% [markdown]
# 👉 Quanto mais repete, mais se aproxima de 0.5

# %% [markdown]
# ## 7. Probabilidade em IA
#
# IA retorna algo assim:
#
# Gato → 0.8
# Cachorro → 0.2
#
# Ela NÃO tem certeza → ela tem probabilidade

# %%
import numpy as np
probabilidade = np.array([0.8, 0.2])
classes = ["Gato", "Cachorro"]
classes[np.argmax(probabilidade)]
# Out:
# 'Gato'

# %% [markdown]
# ## 8. Interpretação MUITO importante
#
# 0.8 NÃO significa certeza
# Significa: “alta chance baseada nos dados”

# %% [markdown]
# ## 9. Simulação de classificador

# %%
# simulando previsões
probabilidade = [
    [0.6, 0.4],
    [0.2, 0.8],
    [0.9, 0.1]
]
classes = ["A", "B"]
[classes[np.argmax(p)] for p in probabilidade]
# Out:
# ['A', 'B', 'A']

# %%
for p in probabilidade:
    print(classes[np.argmax(p)])
# Out:
# A
# B
# A

# %% [markdown]
# ## 10. Exercícios
#
# 1. Probabilidade de sair número ímpar menor que 5?
# 2. Probabilidade de cara duas vezes?
# 3. Se IA diz 0.95, o que significa?

# %%
# Probabilidade de sair número ímpar menor que 5?
dado = [1, 2, 3, 4, 5, 6]
evento = [1, 3]
probabilidade = len(evento) / len(dado)
print(f'A probabilidade menor que 5 e: {probabilidade*100}%')
# Out:
# A probabilidade e: 33.33333333333333%

# %%
# Probabilidade de cara duas vezes?
import random
moeda = ["cara", "coroa"]
evento = ["cara", "cara"]
sucesso = 0
n = 100000
for _ in range(n):
    c1 = random.choice(moeda)
    c2 = random.choice(moeda)
    if c1 == "cara" and c2 == "cara":
        sucesso += 1
sucesso / n
# Out:
# 0.24878

# %% [markdown]
# # Se IA diz 0.95, o que significa?
# Significa que a probabilidade é alta.

# %% [markdown]
# ## 11. Desafio IA
#
# Crie um sistema:
#
# Entrada: probabilidades
# Saída: decisão da IA

# %%
entrada = [
    [0.6, 0.4],
    [0.2, 0.5],
]
evento = ["A", "B"]
[evento[np.argmax(p)] for p in entrada]
# Out:
# ['A', 'B']

# %%
for p in entrada:
    print(evento[np.argmax(p)])
# Out:
# A
# B

# %% [markdown]
# ## 12. Fechamento (para levar pra vida)
#
# * IA NÃO toma decisões certas
# * IA toma decisões PROVÁVEIS
#
# Isso muda completamente a forma de pensar sistemas inteligentes.
